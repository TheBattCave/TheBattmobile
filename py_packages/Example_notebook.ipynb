# %% [markdown]
# # Magic Metro Bus

# %% [markdown]
# ### Example notebook to demonstrate package capabilities

# %% [markdown]
# ### Auto sorting the data

# %% [markdown]
# Ensure there is a folder titled 'Raw Data' in your current directory containing KCM-data-files.zip, then import the function:

# %%
import auto_sort_data
# Out:
# Copied: 14B0081_ProfileData_20180328070533.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016062051.csv to sorted_data
# Copied: 13K0024_ProfileData_20180629074438.csv to sorted_data
# Copied: 14g0176_ProfileData_20170819090921.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016071947.csv to sorted_data
# Copied: 14J0261_ProfileData_20180102062006.csv to sorted_data
# Copied: 14H0215_ProfileData_20171102093205.csv to sorted_data
# Copied: 14h0196_ProfileData_20180316071500.csv to sorted_data
# Copied: 13L0029_ProfileData_20180104092629.csv to sorted_data
# Copied: 14E029_ProfileData_20181106065943.csv to sorted_data
# Copied: ProfileData_20190206084554.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720063451.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720072247.csv to sorted_data
# Copied: 14j0-251_ProfileData_20170423110421.csv to sorted_data
# Copied: 14L0310_ProfileData_20170710062056.csv to sorted_data
# Copied: 14J0233_ProfileData_20180605101826.csv to sorted_data
# Copied: 13J0016_ProfileData_20181022093417.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016080131.csv to sorted_data
# Copied: 14H0220_ProfileData_20181218082248.csv to sorted_data
# Copied: 14j0240_ProfileData_20181218113932.csv to sorted_data
# Copied: 14D0100_ProfileData_20180427062512.csv to sorted_data
# Copied: 14j0242_ProfileData_20170901115702.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016072732.csv to sorted_data
# Copied: 14J0248_ProfileData_20170918104204.csv to sorted_data
# Copied: 15l1009_ProfileData_20181128101123.csv to sorted_data
# Copied: 14LK0310_ProfileData_20180126060958.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720072107.csv to sorted_data
# Copied: 13L0029_ProfileData_20180104102300.csv to sorted_data
# Copied: 14H0222_ProfileData_20180618101602.csv to sorted_data
# Copied: 0012_ProfileData_20161011104849.csv to sorted_data
# Copied: 14E0134_ProfileData_20170905084724.csv to sorted_data
# Copied: 0029_ProfileData_20171219061348.csv to sorted_data
# Copied: 14f0160_ProfileData_20170627060817.csv to sorted_data
# Copied: 14E0114_ProfileData_20171110064258.csv to sorted_data
# Copied: 14f0147_ProfileData_20190118123106.csv to sorted_data
# Copied: 14L0310_ProfileData_20180126063101.csv to sorted_data
# Copied: 13e0-010_ProfileData_20170813065759.csv to sorted_data
# Copied: 13j0016_ProfileData_20190121123034.csv to sorted_data
# Copied: 14b0065_ProfileData_20171014113734.csv to sorted_data
# Copied: 15m1087_ProfileData_20190221132035.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016062212.csv to sorted_data
# Copied: 14B0061_ProfileData_20180328104717.csv to sorted_data
# Copied: 14D0106_ProfileData_20180405093921.csv to sorted_data
# Copied: 14h0226_ProfileData_20190121134100.csv to sorted_data
# Copied: 16e1449_ProfileData_20180828114352.csv to sorted_data
# Copied: 14e0125_ProfileData_20181211062101.csv to sorted_data
# Copied: 134700Q_ProfileData_20180426101830.csv to sorted_data
# Copied: 13L0036_ProfileData_20171007065133.csv to sorted_data
# Copied: 14E0141_ProfileData_20171030074645.csv to sorted_data
# Copied: 13l0029_ProfileData_20180104102759.csv to sorted_data
# Copied: 15m1087_ProfileData_20190222101141.csv to sorted_data
# Copied: 14F0160_ProfileData_20180102095359.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720074310.csv to sorted_data
# Copied: 14h0215_ProfileData_20170814095147.csv to sorted_data
# Copied: 14H0221_ProfileData_20171027081821.csv to sorted_data
# Copied: 14h0222_ProfileData_20180618140455.csv to sorted_data
# Copied: 14b0065_ProfileData_20171014110120.csv to sorted_data
# Copied: 14E0112_ProfileData_20170907070549.csv to sorted_data
# Copied: 14f0147_ProfileData_20180423080620.csv to sorted_data
# Copied: 14j0233_ProfileData_20171219113548.csv to sorted_data
# Copied: 14G0173_ProfileData_20180612092607.csv to sorted_data
# Copied: 14E0126_ProfileData_20181215051937.csv to sorted_data
# Copied: 14E0141_ProfileData_20180503082131.csv to sorted_data
# Copied: 14k0274_ProfileData_20170804094406.csv to sorted_data
# Copied: 140168_ProfileData_20180607103335.csv to sorted_data
# Copied: 14H0197_ProfileData_20180305135045.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016100123.csv to sorted_data
# Copied: 14K0273_ProfileData_20180709062001.csv to sorted_data
# Copied: 14KTEST_ProfileData_20170927120444.csv to sorted_data
# Copied: 14H0199_ProfileData_20181108073954.csv to sorted_data
# Copied: 7031 14D0098_ProfileData_20170927101208.csv to sorted_data
# Copied: 15l1009_ProfileData_20181128100131.csv to sorted_data
# Copied: 14H0221_ProfileData_20171005100537.csv to sorted_data
# Copied: 14l0310_ProfileData_20181217071737.csv to sorted_data
# Copied: 14G0175_ProfileData_20170809094109.csv to sorted_data
# Copied: 13l0056_ProfileData_20170821070915.csv to sorted_data
# Copied: 14D0092_ProfileData_20181210082625.csv to sorted_data
# Copied: 13L0027_ProfileData_20170629120024.csv to sorted_data
# Copied: 14H0204_ProfileData_20180316085333.csv to sorted_data
# Copied: 14j0239_ProfileData_20190109081407.csv to sorted_data
# Copied: 14k0278_ProfileData_20180908113348.csv to sorted_data
# Copied: 14G0173_ProfileData_20180129074057.csv to sorted_data
# Copied: 0_ProfileData_20180119092704.csv to sorted_data
# Copied: 14d0091_ProfileData_20190121135348.csv to sorted_data
# Copied: 14b0065_ProfileData_20171014124522.csv to sorted_data
# Copied: 13L0029_ProfileData_20180105064124.csv to sorted_data
# Copied: 13L0035_ProfileData_20170919113854.csv to sorted_data
# Copied: 14B0060_ProfileData_20180619102852.csv to sorted_data
# Copied: 14K0280_ProfileData_20180220133706.csv to sorted_data
# Copied: 14J0248_ProfileData_20170918104519.csv to sorted_data
# Copied: 14H0197_ProfileData_20171120062357.csv to sorted_data
# Copied: 14G0189_ProfileData_20170804061245.csv to sorted_data
# Copied: 134600G_ProfileData_20180622075420.csv to sorted_data
# Copied: 14H0231_ProfileData_20180321061127.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720073327.csv to sorted_data
# Copied: 14J0247_ProfileData_20170826052149.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016061937.csv to sorted_data
# Copied: 14f0147_ProfileData_20190121080550.csv to sorted_data
# Copied: 14F0152_ProfileData_20170703060703.csv to sorted_data
# Copied: 14E0138_ProfileData_20180215061809.csv to sorted_data
# Copied: 0014_ProfileData_20161004063626.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016105506.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720065005.csv to sorted_data
# Copied: 14E0119_ProfileData_20180619072154.csv to sorted_data
# Copied: 14H0206_ProfileData_20171005122254.csv to sorted_data
# Copied: ProfileData_20190221092144.csv to sorted_data
# Copied: 14G0175_ProfileData_20180425074227.csv to sorted_data
# Copied: 14J0249_ProfileData_20171206061747.csv to sorted_data
# Copied: 13j0016_ProfileData_20181022100422.csv to sorted_data
# Copied: 13L0038_ProfileData_20180517060858.csv to sorted_data
# Copied: 14G0189_ProfileData_20171102121348.csv to sorted_data
# Copied: 14F0160_ProfileData_20180511062344.csv to sorted_data
# Copied: 14F0168_ProfileData_20180119085327.csv to sorted_data
# Copied: 14J0233_ProfileData_20171012134802.csv to sorted_data
# Copied: 13j0016_ProfileData_20180920062321.csv to sorted_data
# Copied: 14J0252_ProfileData_20171127063745.csv to sorted_data
# Copied: 14B0081_ProfileData_20180910122753.csv to sorted_data
# Copied: 14D0107_ProfileData_20170911061836.csv to sorted_data
# Copied: 14E0132_ProfileData_20180301100511.csv to sorted_data
# Copied: 14B0060_ProfileData_20180619081056.csv to sorted_data
# Copied: 14b0060_ProfileData_20180219053225.csv to sorted_data
# Copied: 0016_ProfileData_20180731063048.csv to sorted_data
# Copied: 14D0107_ProfileData_20180307113902.csv to sorted_data
# Copied: 14g0181_ProfileData_20180730084016.csv to sorted_data
# Copied: 14E0129_ProfileData_20180329114429.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016064655.csv to sorted_data
# Copied: 14K0272_ProfileData_20180705080257.csv to sorted_data
# Copied: 13L0048_ProfileData_20180423115704.csv to sorted_data
# Copied: 16b1216_ProfileData_20171207105655.csv to sorted_data
# Copied: 13L0027_ProfileData_20171226084906.csv to sorted_data
# Copied: 14L0292_ProfileData_20180220113848.csv to sorted_data
# Copied: 14B0081_ProfileData_20171027123841.csv to sorted_data
# Copied: 14H0199_ProfileData_20180130101110.csv to sorted_data
# Copied: 14E0126_ProfileData_20181215054010.csv to sorted_data
# Copied: 13l005_ProfileData_20180621083618.csv to sorted_data
# Copied: 13l0033_ProfileData_20180817063925.csv to sorted_data
# Copied: 14L0305_ProfileData_20180228125434.csv to sorted_data
# Copied: 14J0258_ProfileData_20171120073604.csv to sorted_data
# Copied: 14J0271_ProfileData_20181017064355.csv to sorted_data
# Copied: 114J248_ProfileData_20170919060329.csv to sorted_data
# Copied: 15M1074_ProfileData_20181126082100.csv to sorted_data
# Copied: 14B0081_ProfileData_20171027134910.csv to sorted_data
# Copied: 13L0040_ProfileData_20180613083015.csv to sorted_data
# Copied: 14D0088_ProfileData_20170926113406.csv to sorted_data
# Copied: 14H0213_ProfileData_20171020121146.csv to sorted_data
# Copied: 14G0179_ProfileData_20170713121021.csv to sorted_data
# Copied: 140274_ProfileData_20181116103702.csv to sorted_data
# Copied: 13L0049_ProfileData_20170926064203.csv to sorted_data
# Copied: 14e0134_ProfileData_20190116093145.csv to sorted_data
# Copied: 15L0927_ProfileData_20180720115447.csv to sorted_data
# Copied: 14D0104_ProfileData_20170731115307.csv to sorted_data
# Copied: 14J248_ProfileData_20170918120641.csv to sorted_data
# Copied: 14E0119_ProfileData_20180619062346.csv to sorted_data
# Copied: 14f0150_ProfileData_20180927062130.csv to sorted_data
# Copied: 14H0199_ProfileData_20181129103004.csv to sorted_data
# Copied: 14J0262_ProfileData_20180328084446.csv to sorted_data
# Copied: 14J0265_ProfileData_20170801121319.csv to sorted_data
# Copied: 14G0175_ProfileData_20180124061443.csv to sorted_data
# Copied: 14F0161_ProfileData_20180409094810.csv to sorted_data
# Copied: 13E0009_ProfileData_20180629082011.csv to sorted_data
# Copied: 14b0081_ProfileData_20180910122446.csv to sorted_data
# Copied: ProfileData_20171011121413.csv to sorted_data
# Copied: 14L0301_ProfileData_20180403123345.csv to sorted_data
# Copied: 14K0281_ProfileData_20181017115435.csv to sorted_data
# Copied: _ProfileData_20180508065837.csv to sorted_data
# Copied: 14G0175_ProfileData_20180629101822.csv to sorted_data
# Copied: 15l0989_ProfileData_20180723075328.csv to sorted_data
# Copied: 14G0182_ProfileData_20180223062115.csv to sorted_data
# Copied: 13l0029_ProfileData_20180104101217.csv to sorted_data
# Copied: 14e0119_ProfileData_20180315075747.csv to sorted_data
# Copied: 13L0054_ProfileData_20170717075307.csv to sorted_data
# Copied: 14g0-185_ProfileData_20170813085313.csv to sorted_data
# Copied: 14h0211_ProfileData_20180611101602.csv to sorted_data
# Copied: 0_ProfileData_20180213082442.csv to sorted_data
# Copied: 14F0158_ProfileData_20180410104728.csv to sorted_data
# Copied: 14H0218_ProfileData_20180508084201.csv to sorted_data
# Copied: 14j0249_ProfileData_20181212102049.csv to sorted_data
# Copied: 13j0016_ProfileData_20181206062942.csv to sorted_data
# Copied: 14b0065_ProfileData_20171014124035.csv to sorted_data
# Copied: 0016_ProfileData_20180731064002.csv to sorted_data
# Copied: 17d0027_ProfileData_20180719104133.csv to sorted_data
# Copied: 13J0014_ProfileData_20180801084738.csv to sorted_data
# Copied: 14F0161_ProfileData_20180612124325.csv to sorted_data
# Copied: 14d0091_ProfileData_20190130100241.csv to sorted_data
# Copied: 14H01976_ProfileData_20180215075611.csv to sorted_data
# Copied: 13J0016_ProfileData_20180320103531.csv to sorted_data
# Copied: 14H0213_ProfileData_20180404105043.csv to sorted_data
# Copied: 14D0098_ProfileData_20181016073828.csv to sorted_data
# Copied: 14B0080_ProfileData_20170905062848.csv to sorted_data
# Copied: 13l0046_ProfileData_20171220100302.csv to sorted_data
# Copied: 15l1009_ProfileData_20181128094400.csv to sorted_data
# Copied: 14L0215_ProfileData_20180228102206.csv to sorted_data
# Copied: 14H0231_ProfileData_20170626061409.csv to sorted_data
# Copied: 14f0150_ProfileData_20180927080803.csv to sorted_data
# Copied: 14H0196_ProfileData_20180927101225.csv to sorted_data
# Copied: 14e0132_ProfileData_20190111123728.csv to sorted_data
# Copied: 13J0016_ProfileData_20170920063536.csv to sorted_data
# Copied: 14j0238_ProfileData_20180919062724.csv to sorted_data
# Copied: 14J0242_ProfileData_20180301061854.csv to sorted_data
# Copied: 14J0248_ProfileData_20170801075154.csv to sorted_data
# Copied: 14E0133_ProfileData_20180402121944.csv to sorted_data
# Copied: 14H0220_ProfileData_20181105100655.csv to sorted_data
# Copied: 14h0211_ProfileData_20180611083205.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720062549.csv to sorted_data
# Copied: 14E0129_ProfileData_20181105122206.csv to sorted_data
# Copied: 14H0197_ProfileData_20180305134319.csv to sorted_data
# Copied: 14j0240_ProfileData_20181218124816.csv to sorted_data
# Copied: 14J0258_ProfileData_20170712071805.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016064815.csv to sorted_data
# Copied: 14J0249_ProfileData_20181215091532.csv to sorted_data
# Copied: 13J0016_ProfileData_20180920063036.csv to sorted_data
# Copied: 14E0205_ProfileData_20171204081059.csv to sorted_data
# Copied: 13l0036_ProfileData_20171007062944.csv to sorted_data
# Copied: 14b0079_ProfileData_20170814070322.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016093342.csv to sorted_data
# Copied: 14h0197_ProfileData_20181205073755.csv to sorted_data
# Copied: 0_ProfileData_20180621094952.csv to sorted_data
# Copied: 13l0055_ProfileData_20180621084058.csv to sorted_data
# Copied: 13j0016_ProfileData_20181226122024.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016062525.csv to sorted_data
# Copied: 14h0211_ProfileData_20180611084857.csv to sorted_data
# Copied: 14J0262_ProfileData_20171214061408.csv to sorted_data
# Copied: 14m0060_ProfileData_20190221082411.csv to sorted_data
# Copied: 13j0016_ProfileData_20181226103548.csv to sorted_data
# Copied: 14h0222_ProfileData_20180618141226.csv to sorted_data
# Copied: 14D0100_ProfileData_20180410081915.csv to sorted_data
# Copied: 14====0119_ProfileData_20180315062247.csv to sorted_data
# Copied: 14B0077_ProfileData_20180223080044.csv to sorted_data
# Copied: 13L0029_ProfileData_20170726122620.csv to sorted_data
# Copied: 14E0119_ProfileData_20170914085215.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016061448.csv to sorted_data
# Copied: 14J0255_ProfileData_20180314093401.csv to sorted_data
# Copied: 14C0084_ProfileData_20180122075308.csv to sorted_data
# Copied: 16B1192_ProfileData_20171120095113.csv to sorted_data
# Copied: 0014_ProfileData_20161201100821.csv to sorted_data
# Copied: 14K0279_ProfileData_20171031061331.csv to sorted_data
# Copied: 14D0110_ProfileData_20170925082011.csv to sorted_data
# Copied: 13j0016_ProfileData_20181226081031.csv to sorted_data
# Copied: 14K0278_ProfileData_20180213073058.csv to sorted_data
# Copied: 14J0266_ProfileData_20181129072528.csv to sorted_data
# Copied: 16d1316_ProfileData_20190103070554.csv to sorted_data
# Copied: 14H0204_ProfileData_20180914075228.csv to sorted_data
# Copied: _ProfileData_20180508073011.csv to sorted_data
# Copied: 13j0016_ProfileData_20181226103058.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016075629.csv to sorted_data
# Copied: 0009_ProfileData_20170420082442.csv to sorted_data
# Copied: 14K0277_ProfileData_20180430085436.csv to sorted_data
# Copied: 14H0197_ProfileData_20180305134743.csv to sorted_data
# Copied: 13L0031_ProfileData_20180220083030.csv to sorted_data
# Copied: 14H0198_ProfileData_20170918063607.csv to sorted_data
# Copied: 14J042_ProfileData_20170626074940.csv to sorted_data
# Copied: 14H0218_ProfileData_20180213123311.csv to sorted_data
# Copied: 14j0238_ProfileData_20180801062601.csv to sorted_data
# Copied: 0014_ProfileData_20160727062458.csv to sorted_data
# Copied: 14E0138_ProfileData_20171204061820.csv to sorted_data
# Copied: 14J0242_ProfileData_20171205105105.csv to sorted_data
# Copied: 14g0182_ProfileData_20180531104618.csv to sorted_data
# Copied: 14F0158_ProfileData_20171110095939.csv to sorted_data
# Copied: 14l0310_ProfileData_20181217074012.csv to sorted_data
# Copied: 14K0287_ProfileData_20180409133321.csv to sorted_data
# Copied: 14D0110_ProfileData_20180213061854.csv to sorted_data
# Copied: 15M1087_ProfileData_20171027063252.csv to sorted_data
# Copied: 14H0197_ProfileData_20180305122613.csv to sorted_data
# Copied: 14K0115_ProfileData_20180626084731.csv to sorted_data
# Copied: 14K0115_ProfileData_20180605134554.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016080433.csv to sorted_data
# Copied: 0036_ProfileData_20171007063049.csv to sorted_data
# Copied: 14F0169_ProfileData_20170725061548.csv to sorted_data
# Copied: 16e1449_ProfileData_20180828115648.csv to sorted_data
# Copied: 14K0277_ProfileData_20180112080306.csv to sorted_data
# Copied: 14H0211_ProfileData_20180611061713.csv to sorted_data
# Copied: 15l0927_ProfileData_20180720083329.csv to sorted_data
# Copied: 15m1087_ProfileData_20190222102140.csv to sorted_data
# Copied: 14J0265_ProfileData_20180122061159.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016063125.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016081046.csv to sorted_data
# Copied: 14E0141_ProfileData_20170717061549.csv to sorted_data
# Copied: 13L0035_ProfileData_20180118080858.csv to sorted_data
# Copied: ProfileData_20171010124423.csv to sorted_data
# Copied: !3J0018_ProfileData_20170920082828.csv to sorted_data
# Copied: 14E029_ProfileData_20181106072233.csv to sorted_data
# Copied: 14H0198_ProfileData_20170918105158.csv to sorted_data
# Copied: 13j0016_ProfileData_20181205133509.csv to sorted_data
# Copied: 14H0222_ProfileData_20171113133631.csv to sorted_data
# Copied: 15h0757_ProfileData_20180912062854.csv to sorted_data
# Copied: _ProfileData_20180611101359.csv to sorted_data
# Copied: 1346-009_ProfileData_20171120114956.csv to sorted_data
# Copied: 13L0050_ProfileData_20180330093839.csv to sorted_data
# Copied: _ProfileData_20180719104226.csv to sorted_data
# Copied: 1346-00g_ProfileData_20180621095005.csv to sorted_data
# Copied: 13J0014_ProfileData_20180802094539.csv to sorted_data
# Copied: 13l0029_ProfileData_20180104104356.csv to sorted_data
# Copied: 14l0177_ProfileData_20180703064758.csv to sorted_data
# Copied: 14J0252_ProfileData_20180327120724.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016094817.csv to sorted_data
# Copied: 14F0150_ProfileData_20170717095516.csv to sorted_data
# Copied: 14e0119_ProfileData_20180315062511.csv to sorted_data
# Copied: 14D0107_ProfileData_20180105102220.csv to sorted_data
# Copied: 14H0196_ProfileData_20180521115019.csv to sorted_data
# Copied: 14H0218_ProfileData_20181017093450.csv to sorted_data
# Copied: 14E0132_ProfileData_20180301103618.csv to sorted_data
# Copied: 14l0310_ProfileData_20181217073017.csv to sorted_data
# Copied: 1350-005_ProfileData_20190117124216.csv to sorted_data
# Copied: 14G0181_ProfileData_20171116102242.csv to sorted_data
# Copied: 14J0248_ProfileData_20170918130814.csv to sorted_data
# Copied: 14J258_ProfileData_20171229125308.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016074310.csv to sorted_data
# Copied: 14L0292_ProfileData_20170731092717.csv to sorted_data
# Copied: 14J0247_ProfileData_20180425115139.csv to sorted_data
# Copied: 14E0112_ProfileData_20171030103724.csv to sorted_data
# Copied: 14F0168_ProfileData_20180607122634.csv to sorted_data
# Copied: 14l0301_ProfileData_20171009074203.csv to sorted_data
# Copied: 14j0249_ProfileData_20181212095657.csv to sorted_data
# Copied: 17d0027_ProfileData_20180719104742.csv to sorted_data
# Copied: 13L0036_ProfileData_20170706075916.csv to sorted_data
# Copied: 14B0059_ProfileData_20180403061303.csv to sorted_data
# Copied: 1480199_ProfileData_20181108072649.csv to sorted_data
# Copied: 13L0029_ProfileData_20180104101913.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016075221.csv to sorted_data
# Copied: 15l0927_ProfileData_20180720114359.csv to sorted_data
# Copied: 14B0080_ProfileData_20180308074404.csv to sorted_data
# Copied: 14J0248_ProfileData_20170918121959.csv to sorted_data
# Copied: 0012_ProfileData_20161115073634.csv to sorted_data
# Copied: 14b0065_ProfileData_20171014113030.csv to sorted_data
# Copied: 14F0154_ProfileData_20171116125343.csv to sorted_data
# Copied: 13l0033_ProfileData_20180817064310.csv to sorted_data
# Copied: 14K0274_ProfileData_20180220063904.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016065139.csv to sorted_data
# Copied: 14j0248_ProfileData_20170918102838.csv to sorted_data
# Copied: 14F0158_ProfileData_20170826114005.csv to sorted_data
# Copied: 13L0038_ProfileData_20180223095904.csv to sorted_data
# Copied: 14g0182_ProfileData_20181228122043.csv to sorted_data
# Copied: 14G0175_ProfileData_20180424114019.csv to sorted_data
# Copied: 14h0196_ProfileData_20180315133657.csv to sorted_data
# Copied: 14J0248_ProfileData_20170918135132.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016101153.csv to sorted_data
# Copied: 14H0036_ProfileData_20171030061435.csv to sorted_data
# Copied: 14D0094_ProfileData_20180131081250.csv to sorted_data
# Copied: 0012_ProfileData_20161012071640.csv to sorted_data
# Copied: ProfileData_20171009073202.csv to sorted_data
# Copied: 14E0141_ProfileData_20180503083300.csv to sorted_data
# Copied: 0024_ProfileData_20180625071153.csv to sorted_data
# Copied: 14e0126_ProfileData_20181215053028.csv to sorted_data
# Copied: 0016_ProfileData_20180731061359.csv to sorted_data
# Copied: 14F0145_ProfileData_20180108080500.csv to sorted_data
# Copied: 16A1188_ProfileData_20180214104625.csv to sorted_data
# Copied: 14h0226_ProfileData_20181221081219.csv to sorted_data
# Copied: 14H0222_ProfileData_20180618122646.csv to sorted_data
# Copied: 14D0104_ProfileData_20180503115805.csv to sorted_data
# Copied: 14k0287_ProfileData_20170901074050.csv to sorted_data
# Copied: 14J0248_ProfileData_20170918103745.csv to sorted_data
# Copied: 14G0175_ProfileData_20180425073232.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720065633.csv to sorted_data
# Copied: 14f0152_ProfileData_20181212093518.csv to sorted_data
# Copied: 14e0132_ProfileData_20170926093904.csv to sorted_data
# Copied: 13l0033_ProfileData_20180817064530.csv to sorted_data
# Copied: 14H0198_ProfileData_20180530081319.csv to sorted_data
# Copied: 14k0287_ProfileData_20170901082243.csv to sorted_data
# Copied: 13j0016_ProfileData_20181226115443.csv to sorted_data
# Copied: 1350-005_ProfileData_20190117123611.csv to sorted_data
# Copied: 13J0016_ProfileData_20180920063914.csv to sorted_data
# Copied: 14j0249_ProfileData_20181212101843.csv to sorted_data
# Copied: 140071_ProfileData_20180614063540.csv to sorted_data
# Copied: 14J0238_ProfileData_20180629132752.csv to sorted_data
# Copied: 134700R_ProfileData_20180426102521.csv to sorted_data
# Copied: 14H0205_ProfileData_20171204082350.csv to sorted_data
# Copied: 13L0036_ProfileData_20171007062240.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016095738.csv to sorted_data
# Copied: 15L0990_ProfileData_20181011101019.csv to sorted_data
# Copied: 0014_ProfileData_20170207092734.csv to sorted_data
# Copied: 14d0106_ProfileData_20190207124506.csv to sorted_data
# Copied: 14H0198_ProfileData_20180226064006.csv to sorted_data
# Copied: 14h0211_ProfileData_20180611075543.csv to sorted_data
# Copied: 14J0261_ProfileData_20180501061929.csv to sorted_data
# Copied: 14H0229_ProfileData_20171211062821.csv to sorted_data
# Copied: 13l005_ProfileData_20180621084254.csv to sorted_data
# Copied: 14H0231_ProfileData_20181112115554.csv to sorted_data
# Copied: 14g0181_ProfileData_20180730084251.csv to sorted_data
# Copied: 14e0129_ProfileData_20171005072448 - Copy.csv to sorted_data
# Copied: 14J0249_ProfileData_20181215083238.csv to sorted_data
# Copied: 14D0096_ProfileData_20171114082344.csv to sorted_data
# Copied: ProfileData_20190221092010.csv to sorted_data
# Copied: 14E0115_ProfileData_20170907100032.csv to sorted_data
# Copied: 1348-008_ProfileData_20180618062414.csv to sorted_data
# Copied: 14f0147_ProfileData_20190121064151.csv to sorted_data
# Copied: 16e1449_ProfileData_20180829080250.csv to sorted_data
# Copied: 14F0159_ProfileData_20171024094443.csv to sorted_data
# Copied: 14J0257_ProfileData_20181022063244.csv to sorted_data
# Copied: 15l1009_ProfileData_20181128094645.csv to sorted_data
# Copied: 14H0222_ProfileData_20180618120833.csv to sorted_data
# Copied: 14J261_ProfileData_20180102061608.csv to sorted_data
# Copied: 15G0743_ProfileData_20181023063755.csv to sorted_data
# Copied: 14E0133_ProfileData_20171228102308.csv to sorted_data
# Copied: 1027_ProfileData_20180508072803.csv to sorted_data
# Copied: 14e0138_ProfileData_20170829124433.csv to sorted_data
# Copied: 14H0197_ProfileData_20180305133851.csv to sorted_data
# Copied: 14J0265_ProfileData_20170801101915.csv to sorted_data
# Copied: 14h0226_ProfileData_20181220083248.csv to sorted_data
# Copied: 14L0309_ProfileData_20180228062309.csv to sorted_data
# Copied: 14H0221_ProfileData_20180403084955.csv to sorted_data
# Copied: 14h0218_ProfileData_20180508093211.csv to sorted_data
# Copied: 14G0185_ProfileData_20180912104151.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016073544.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016062609.csv to sorted_data
# Copied: 14e0119_ProfileData_20190213115724.csv to sorted_data
# Copied: 13d0016_ProfileData_20190122075023.csv to sorted_data
# Copied: 15L1027_ProfileData_20180508064221.csv to sorted_data
# Copied: 14d0091_ProfileData_20190130062835.csv to sorted_data
# Copied: 14k0287_ProfileData_20170901095119.csv to sorted_data
# Copied: 14j0238_ProfileData_20180905071214.csv to sorted_data
# Copied: 14k0278_ProfileData_20180908113610.csv to sorted_data
# Copied: 15L0967_ProfileData_20180511083129.csv to sorted_data
# Copied: 0_ProfileData_20180508073224.csv to sorted_data
# Copied: 14l0302_ProfileData_20180720062110.csv to sorted_data
# Copied: 14J0271_ProfileData_20180227114333.csv to sorted_data
# Copied: 14H0-215_ProfileData_20180908092805.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016101607.csv to sorted_data
# Copied: 1346-00G_ProfileData_20180621094017.csv to sorted_data
# Copied: 14J0252_ProfileData_20180521060949.csv to sorted_data
# Copied: 14B0060_ProfileData_20170629062240.csv to sorted_data
# Copied: 14b0065_ProfileData_20171014123601.csv to sorted_data
# Copied: 14g0176_ProfileData_20180219084425.csv to sorted_data
# Copied: 140222_ProfileData_20180618121054.csv to sorted_data
# Copied: 14j0248_ProfileData_20170918083843.csv to sorted_data
# Copied: 15m1087_ProfileData_20190228084127.csv to sorted_data
# Copied: 14KI0287_ProfileData_20170719060911.csv to sorted_data
# Copied: 13J0011_ProfileData_20180109094425.csv to sorted_data
# Copied: 14H0227_ProfileData_20180129132842.csv to sorted_data
# Copied: 13L0036_ProfileData_20180423062427.csv to sorted_data
# Copied: 14G0185_ProfileData_20171117085207.csv to sorted_data
# Copied: 14L0305_ProfileData_20170727115527.csv to sorted_data
# Copied: ProfileData_20171009134802.csv to sorted_data
# Copied: 13L0055_ProfileData_20180621071301.csv to sorted_data
# Copied: 14H0222_ProfileData_20180618133441.csv to sorted_data
# Copied: 14h0197_ProfileData_20180306065840.csv to sorted_data
# Copied: 140091_ProfileData_20170927061136.csv to sorted_data
# Copied: 14j0262_ProfileData_20170824121647.csv to sorted_data
# Copied: 14K0280_ProfileData_20180405061000.csv to sorted_data
# Copied: 14D0092_ProfileData_20181210081917.csv to sorted_data
# Copied: 14b0079_ProfileData_20181205115218.csv to sorted_data
# Copied: 0010_ProfileData_20170509073635.csv to sorted_data
# Copied: 14E029_ProfileData_20181106071437.csv to sorted_data
# Copied: 14LO0309_ProfileData_20180607061241.csv to sorted_data
# Copied: 14h0197_ProfileData_20180306070303.csv to sorted_data
# Copied: 1346-009_ProfileData_20171120114540.csv to sorted_data
# Copied: 14F0168_ProfileData_20170724083537.csv to sorted_data
# Copied: 124H0222_ProfileData_20180618125643.csv to sorted_data
# Copied: 14h0207_ProfileData_20170828133328.csv to sorted_data
# Copied: 14H0231_ProfileData_20181112115822.csv to sorted_data
# Copied: 14H0197_ProfileData_20180306070911.csv to sorted_data
# Copied: ProfileData_20171011084140.csv to sorted_data
# Copied: 14j0239_ProfileData_20190107121413.csv to sorted_data
# Copied: 14f0160_ProfileData_20170925103224.csv to sorted_data
# Copied: 13L0046_ProfileData_20180112062822.csv to sorted_data
# Copied: 13j0016_ProfileData_20180920070233.csv to sorted_data
# Copied: 14J0251_ProfileData_20180426061246.csv to sorted_data
# Copied: 13L0048_ProfileData_20180423120436.csv to sorted_data
# Copied: 14h0197_ProfileData_20180306065257.csv to sorted_data
# Copied: _ProfileData_20180425073946.csv to sorted_data
# Copied: 14E029_ProfileData_20181106071028.csv to sorted_data
# Copied: 14E029_ProfileData_20181106070632.csv to sorted_data
# Copied: 14J042_ProfileData_20170626074940 - Copy (2).csv to sorted_data
# Copied: 13K0025_ProfileData_20170626100619.csv to sorted_data
# Copied: 14L0305_ProfileData_20180228121421.csv to sorted_data
# Copied: 13L0029_ProfileData_20170726121035.csv to sorted_data
# Copied: 14J0239_ProfileData_20171127080153.csv to sorted_data
# Copied: 14K0291_ProfileData_20181105062204.csv to sorted_data
# Copied: 13L0047_ProfileData_20180306100218.csv to sorted_data
# Copied: 14H0219_ProfileData_20180226083959.csv to sorted_data
# Copied: 14D0094_ProfileData_20171031085145.csv to sorted_data
# Copied: 14H0197_ProfileData_20180305135341.csv to sorted_data
# Copied: 14h0198_ProfileData_20170918064311.csv to sorted_data
# Copied: 14J0247_ProfileData_20180124074245.csv to sorted_data
# Copied: 1350-005_ProfileData_20190117083651.csv to sorted_data
# Copied: 16e1449_ProfileData_20180828114620.csv to sorted_data
# Copied: 13L0029_ProfileData_20170726120120.csv to sorted_data
# Copied: 14J0244_ProfileData_20180511115621.csv to sorted_data
# Copied: 14G0189_ProfileData_20180209073852.csv to sorted_data
# Copied: 14J042_ProfileData_20170626074940 - Copy.csv to sorted_data
# Copied: 13L0037_ProfileData_20171212122155.csv to sorted_data
# Copied: 14B0080_ProfileData_20170905062459.csv to sorted_data
# Copied: 14h0197_ProfileData_20180306065534.csv to sorted_data
# Copied: 14G0173_ProfileData_20170724060811.csv to sorted_data
# Copied: 13L0049_ProfileData_20180126081444.csv to sorted_data
# Copied: 14H0200_ProfileData_20180305103242.csv to sorted_data
# Copied: 3747_ProfileData_20180328135136.csv to sorted_data
# Copied: 14K0288_ProfileData_20180329084055.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016071332.csv to sorted_data
# Copied: 14J0258_ProfileData_20171227082159.csv to sorted_data
# Copied: 14L0047_ProfileData_20170712084559.csv to sorted_data
# Copied: 14G0174_ProfileData_20180625121927.csv to sorted_data
# Copied: 14B0080_ProfileData_20180913073509.csv to sorted_data
# Copied: 13j0016_ProfileData_20180920064815.csv to sorted_data
# Copied: 13l005_ProfileData_20180621085130.csv to sorted_data
# Copied: 14H0197_ProfileData_20180306063502.csv to sorted_data
# Copied: 14m0060_ProfileData_20190213074406.csv to sorted_data
# Copied: 0_ProfileData_20171102122711.csv to sorted_data
# Copied: 14F0147_ProfileData_20190121062936.csv to sorted_data
# Copied: 13L0029_ProfileData_20170726121543.csv to sorted_data
# Copied: 14L0211_ProfileData_20180213114507.csv to sorted_data
# Copied: 14D0100_ProfileData_20180427063335.csv to sorted_data
# Copied: 14G0175_ProfileData_20180425072041.csv to sorted_data
# Copied: 17d0027_ProfileData_20180719113906.csv to sorted_data
# Copied: 14J0239_ProfileData_20171127085327.csv to sorted_data
# Copied: 14J0249_ProfileData_20180521081406.csv to sorted_data
# Copied: 14E0129_ProfileData_20181105123327.csv to sorted_data
# Copied: 14K0278_ProfileData_20170927103316.csv to sorted_data
# Copied: 0011_ProfileData_20170208103957.csv to sorted_data
# Copied: ProfileData_20190221082754.csv to sorted_data
# Copied: 13k0-023_ProfileData_20170812114258.csv to sorted_data
# Copied: 14H0217_ProfileData_20180307083058.csv to sorted_data
# Copied: 14G0175_ProfileData_20180424105332.csv to sorted_data
# Copied: 14H0214_ProfileData_20170720073939.csv to sorted_data
# Copied: 14H0197_ProfileData_20180306071600.csv to sorted_data
# Copied: 13L0309_ProfileData_20180607062937.csv to sorted_data
# Copied: 14B0061_ProfileData_20171205083541.csv to sorted_data
# Copied: 0a121347_ProfileData_20170831092708.csv to sorted_data
# Copied: 14L0299_ProfileData_20170720061319.csv to sorted_data
# Copied: 14K0-278_ProfileData_20180908113110.csv to sorted_data
# Copied: 14E0129_ProfileData_20181105125102.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016075859.csv to sorted_data
# Copied: 13L0051_ProfileData_20170809073147.csv to sorted_data
# Copied: 14f0152_ProfileData_20181214074307.csv to sorted_data
# Copied: 14J0255_ProfileData_20171211121822.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016063342.csv to sorted_data
# Copied: 14e0129_ProfileData_20171005072448.csv to sorted_data
# Copied: 14h0216_ProfileData_20180725065419.csv to sorted_data
# Copied: 13j0016_ProfileData_20181226120838.csv to sorted_data
# Copied: 13l0-053_ProfileData_20170423060219.csv to sorted_data
# Copied: 14L0310_ProfileData_20180126063454.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016073130.csv to sorted_data
# Copied: 14e0129_ProfileData_20180817084634.csv to sorted_data
# Copied: 14H0222_ProfileData_20180618121617.csv to sorted_data
# Copied: 13l0-053_ProfileData_20170423060829.csv to sorted_data
# Copied: 14J0242_ProfileData_20170626075908.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016065903.csv to sorted_data
# Copied: 14H0207_ProfileData_20171031103418.csv to sorted_data
# Copied: 14G0181_ProfileData_20180307061525.csv to sorted_data
# Copied: 14F0161_ProfileData_20180103101858.csv to sorted_data
# Copied: 14G0185_ProfileData_20170629083832.csv to sorted_data
# Copied: 14G0186_ProfileData_20170719092333.csv to sorted_data
# Copied: _ProfileData_20171205102949.csv to sorted_data
# Copied: ProfileData_20181210082536.csv to sorted_data
# Copied: 13j0016_ProfileData_20190121101408.csv to sorted_data
# Copied: 14L0309_ProfileData_20180606134722.csv to sorted_data
# Copied: 14F0168_ProfileData_20171009103627.csv to sorted_data
# Copied: 14j0242_ProfileData_20170901115942.csv to sorted_data
# Copied: 14L0296_ProfileData_20170706061502.csv to sorted_data
# Copied: 14L0310_ProfileData_20171106061454.csv to sorted_data
# Copied: 14C0084_ProfileData_20180731100702.csv to sorted_data
# Copied: 14B0065_ProfileData_20171016062946.csv to sorted_data
# Copied: 14f0169_ProfileData_20180315094035.csv to sorted_data
# Copied: 14M0316_ProfileData_20180530063544.csv to sorted_data
# Copied: 14D0008_ProfileData_20170908104212.csv to sorted_data
# Copied: 14H0199_ProfileData_20181016095307.csv to sorted_data
# Copied: 14D0092_ProfileData_20180227082657.csv to sorted_data

# %% [markdown]
# You should now have 2 new folders: 'sorted_data' containing bus data with no module changes and 'vis_buses' containing data with modules that have been swapped.

# %% [markdown]
# ## Building dataframes from the csv files

# %% [markdown]
# Directly reading the csv files into a dataframe formats the data in an impractical way:

# %%
import pandas as pd

examp_file = auto_sort_data.find_directory() + 'vis_buses/' + 'bus_1/' + '0016_ProfileData_20180731061359.csv'
df = pd.read_csv(examp_file)

df
# Out:
#                                               Unnamed: 1 Unnamed: 2  \
# 0    ESS BMS and Battery Module Profile Data         NaN        NaN
# 1                                        NaN         NaN        NaN
# 2      Data retrieved: 07/31/2018 @ 06:14:11         NaN        NaN
# 3                                        NaN         NaN        NaN
# 4                   BMS Software AS version:  0x0206BA42        NaN
# ..                                       ...         ...        ...
# 954                                      NaN         NaN        NaN
# 955                    <Module Voltages (V)>         NaN        NaN
# 956                                      NaN         NaN        NaN
# 957                                      NaN      < 24.0         24
# 958                                                    0          0
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 954        NaN        NaN        NaN        NaN        NaN        NaN
# 955        NaN        NaN        NaN        NaN        NaN        NaN
# 956        NaN        NaN        NaN        NaN        NaN        NaN
# 957       26.4       28.8       31.2       33.6         36       38.4
# 958          0          0          1      46473    1342848    6421609
#
#     Unnamed: 9  ... Unnamed: 65 Unnamed: 66 Unnamed: 67 Unnamed: 68  \
# 0          NaN  ...         NaN         NaN         NaN         NaN
# 1          NaN  ...         NaN         NaN         NaN         NaN
# 2          NaN  ...         NaN         NaN         NaN         NaN
# 3          NaN  ...         NaN         NaN         NaN         NaN
# 4          NaN  ...         NaN         NaN         NaN         NaN
# ..         ...  ...         ...         ...         ...         ...
# 954        NaN  ...         NaN         NaN         NaN         NaN
# 955        NaN  ...         NaN         NaN         NaN         NaN
# 956        NaN  ...         NaN         NaN         NaN         NaN
# 957       40.8  ...         NaN         NaN         NaN         NaN
# 958     952298  ...         NaN         NaN         NaN         NaN
#
#     Unnamed: 69 Unnamed: 70 Unnamed: 71 Unnamed: 72 Unnamed: 73 Unnamed: 74
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 954         NaN         NaN         NaN         NaN         NaN         NaN
# 955         NaN         NaN         NaN         NaN         NaN         NaN
# 956         NaN         NaN         NaN         NaN         NaN         NaN
# 957         NaN         NaN         NaN         NaN         NaN         NaN
# 958         NaN         NaN         NaN         NaN         NaN         NaN
#
# [959 rows x 75 columns]

# %% [markdown]
# Our data building functions allow the csvs to be parsed into meaningful dataframes for statistical analysis and visualizations.

# %%
import build_data_vis

# %%
directory = build_data_vis.find_directory() + 'vis_buses/'

# %% [markdown]
# The sort_bus_by_date function creates a dataframe that orders the file names for a given bus by date retrieved.

# %%
df_bus_dates = build_data_vis.sort_bus_by_date(directory, 'bus_1/')
df_bus_dates
# Out:
#                                   Filename       DateRetrieved
# 0   13J0016_ProfileData_20170920063536.csv 2017-09-20 06:36:19
# 1   !3J0018_ProfileData_20170920082828.csv 2017-09-20 08:29:04
# 2   13J0016_ProfileData_20180320103531.csv 2018-03-20 10:36:30
# 3      0016_ProfileData_20180731061359.csv 2018-07-31 06:14:11
# 4      0016_ProfileData_20180731063048.csv 2018-07-31 06:30:55
# 5      0016_ProfileData_20180731064002.csv 2018-07-31 06:40:09
# 6   13J0016_ProfileData_20180920063036.csv 2018-09-20 06:30:57
# 7   13J0016_ProfileData_20180920063914.csv 2018-09-20 06:39:31
# 8   13j0016_ProfileData_20180920064815.csv 2018-09-20 06:48:27
# 9   13j0016_ProfileData_20180920070233.csv 2018-09-20 07:02:46
# 10  13J0016_ProfileData_20181022093417.csv 2018-10-22 09:34:57
# 11  13j0016_ProfileData_20181022100422.csv 2018-10-22 10:04:39
# 12  13j0016_ProfileData_20181205133509.csv 2018-12-05 13:35:24
# 13  13j0016_ProfileData_20181206062942.csv 2018-12-06 06:30:40
# 14  13j0016_ProfileData_20181226081031.csv 2018-12-26 08:11:19
# 15  13j0016_ProfileData_20181226122024.csv 2018-12-26 12:20:33
# 16  13j0016_ProfileData_20190121101408.csv 2019-01-21 10:14:16
# 17  13d0016_ProfileData_20190122075023.csv 2019-01-22 07:50:31

# %% [markdown]
# The build_bus_df takes as input a directory, a string of the desired bus directory, and a keyword (selected from 'Current', 'Voltage', or 'Power'. The function returns a dataframe of the entire bus current, voltage, or power over time, with the order of the rows being sequential by date.

# %%
build_data_vis.build_bus_df(directory, 'bus_1/', 'Voltage')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_854/660489402.py in ?()
# ----> 1 build_data_vis.build_bus_df(directory, 'bus_1/', 'Voltage')
#
# ~/TheBattmobile/py_packages/build_data_vis.py in ?(directory, bus_num, keyword)
#      80     for i in range(len(bus_dates)):
#      81         file = bus_dates['Filename'].loc[i]
#      82         file_dir = directory + bus_num + file
#      83         tmp = pd.read_csv(file_dir, header=None, skiprows=row_list)
# ---> 84         bus_parameter = bus_parameter.append(tmp)
#      85         df_index = pd.read_csv(file_dir, header=0, skiprows=index_range)
#      86     bus_parameter.columns = df_index.columns
#      87
#
# ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# The build_module_df function takes as input a directory, a string of the desired bus directory, and an integer module number (can be between 1 and 16). The function returns a dataframe of the module voltages with the rows sequential in time. Note that the module data within the csv files is further subdivided into 12 submodules. Therefore, this function will output 12 rows for each date retrieved within the bus folder. For example, running this function on bus 1 module 1 should return a dataframe with 216 rows. Rows 0-11 correspond to the first date in the bus folder, then rows 12-24 to the next date, etc.

# %%
build_data_vis.build_module_df(directory, 'bus_1/', 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_529/1036780560.py in ?()
# ----> 1 build_data_vis.build_module_df(directory, 'bus_1/', 1)
#
# ~/TheBattmobile/py_packages/build_data_vis.py in ?(directory, bus_num, module_num)
#     103     for i in range(len(bus_dates)):
#     104         file = bus_dates['Filename'].loc[i]
#     105         file_dir = directory + bus_num + file
#     106         tmp = pd.read_csv(file_dir, header=None, skiprows=row_list)
# --> 107         module_df = module_df.append(tmp)
#     108     df_index = pd.read_csv(file_dir, header=0, skiprows=index_range)
#     109     module_df.columns = df_index.columns
#     110
#
# ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# The build_module_df function is similar to the above function, but it averages the submodule data together to return only one row for each date for the module specified. This allows for easier visualization of voltages on the module level.

# %%
build_data_vis.build_module_average_df(directory, 'bus_1/', 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_529/3227922098.py in ?()
# ----> 1 build_data_vis.build_module_average_df(directory, 'bus_1/', 1)
#
# ~/TheBattmobile/py_packages/build_data_vis.py in ?(directory, bus_num, module_num)
#     128         tmp = pd.read_csv(file_dir, header=None, skiprows=row_list)
#     129         tmp = tmp.dropna(axis=1)
#     130         tmp = tmp.drop(0, axis=1)
#     131         tmp_ave = tmp.mean()
# --> 132         module_average_df = module_average_df.append(tmp_ave,
#     133                                                      ignore_index=True)
#     134
#     135     df_index = pd.read_csv(file_dir, header=0, skiprows=index_range)
#
# ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# The count_mod_changes function takes as an input a directory of data sorted by bus. The function will then return a dataframe showing the bus and module number as well as the number of times the module has been changed.

# %%
build_data_vis.count_mod_changes(directory)
# Out:
#    Bus Module                  Date  Change
# 0    1      1  09/20/2017, 06:36:19       0
# 1    1      1  09/20/2017, 08:29:04       0
# 2    1      1  03/20/2018, 10:36:30       0
# 3    1      1  07/31/2018, 06:14:11       0
# 4    1      1  07/31/2018, 06:30:55       0
# ..  ..    ...                   ...     ...
# 59  98     15  05/30/2018, 08:13:37       1
# 60  98     16  09/18/2017, 06:43:27       0
# 61  98     16  09/18/2017, 10:52:47       1
# 62  98     16  02/26/2018, 06:40:43       1
# 63  98     16  05/30/2018, 08:13:37       1
#
# [4384 rows x 4 columns]

# %% [markdown]
# The find_replaced_modules function takes as an input a directory of data sorted by bus. The function will return a dictionary with the bus number as the key and the serial number of the modules that have full lifetime data as the values.

# %%
build_data_vis.find_replaced_modules(directory)
# Out:
# {'bus_1': [' 0039-1811-00U-402335-00804......'],
#  'bus_10': [' 0039-1638-0HC-402335-00802..&...'],
#  'bus_154': [" 0039-1635-06T-402335-00802..'..."],
#  'bus_2': [' 0039-1522-04F-402335-00710......',
#   ' 0039-1602-0L2-402335-00710......',
#   ' 0039-0951-0DM-402335-00108..&...',
#   ' 0039-1641-0P2-402335-00802..)...',
#   ' 364A1585G3REVA-14A3920..........',
#   ' 0039-1632-0UG-402335-00710.. ...',
#   ' 0039-1641-0PD-402335-00802..)...',
#   ' 364A1585G3REVA-14A3924..........',
#   ' 0039-0951-0HB-402335-00108..&...',
#   ' 0039-1632-0UH-402335-00710.. ...',
#   ' 0039-1630-0LT-402335-00710......',
#   ' 0039-1632-0UP-402335-00710.. ...',
#   ' 364A1585G3REVA-14A3925..........',
#   ' 364A1585G3REVA-14A3919..........',
#   ' 364A1585G3REVA-14A3917..........',
#   ' 0039-1632-0UL-402335-00710.. ...',
#   ' 0039-1630-0LW-402335-00710......',
#   ' 0039-1630-0LV-402335-00710......',
#   ' 364A1583G100-13L0049............',
#   ' 0039-0951-0DP-402335-00108..&...',
#   ' 0039-1630-0M2-402335-00710......',
#   ' 0039-1632-0UK-402335-00710.. ...',
#   ' 0039-1641-0P7-402335-00802..)...',
#   ' 0039-1632-0UN-402335-00710.. ...',
#   ' 0039-1608-0RJ-402335-00710......',
#   ' 13E0010.........................',
#   ' 0039-1602-0L3-402335-00710......',
#   ' 0039-1630-0M0-402335-00710......',
#   ' 0039-1630-0M1-402335-00710......',
#   ' 0039-1632-0UC-402335-00710.. ...',
#   ' 0039-1632-0U8-402335-00710.. ...',
#   ' 0039-1632-0UE-402335-00710.. ...',
#   ' 0039-0951-0HL-402335-00108..&...',
#   ' 364A1585G3REVA-14A3916..........',
#   ' 0039-1630-0LZ-402335-00710......'],
#  'bus_44': [' 0A12-1329-0CG-402335-00613......'],
#  'bus_67': [' 0039-1639-061-402335-00802..&...']}

# %% [markdown]
# The swapped_module_dataframes function takes as an input a directory, a module serial number, and a keyword. The function then returns a dataframe of the input module characteristic. For example, inputting your directory with the serial number for bus 1 module 1 and the keyword 'balancers' will return a dataframe of the cell balancer data for that module, with the rows sequential by time.

# %%
build_data_vis.swapped_mod_dataframes(directory, ' 0039-1811-00U-402335-00804......', 'balancers')
# Out:
# [                                            Off      On    TOTAL
#  <Cell Balancers>  09/20/2018, 06:30:57
#  CELL 1                                  1030246  106943  1137189
#  CELL 2                                  1028063  109126  1137189
#  CELL 3                                  1029071  108118  1137189
#  CELL 4                                  1027367  109822  1137189
#  CELL 5                                  1028041  109148  1137189
#  CELL 6                                  1026996  110193  1137189
#  CELL 7                                  1028023  109166  1137189
#  CELL 8                                  1025681  111508  1137189
#  CELL 9                                  1026528  110661  1137189
#  CELL 10                                 1023558  113631  1137189
#  CELL 11                                 1022981  114208  1137189
#  CELL 12                                 1025729  111460  1137189,
#                                              Off      On    TOTAL
#  <Cell Balancers>  09/20/2018, 06:39:31
#  CELL 1                                  1030651  106943  1137594
#  CELL 2                                  1028468  109126  1137594
#  CELL 3                                  1029476  108118  1137594
#  CELL 4                                  1027772  109822  1137594
#  CELL 5                                  1028446  109148  1137594
#  CELL 6                                  1027401  110193  1137594
#  CELL 7                                  1028428  109166  1137594
#  CELL 8                                  1026086  111508  1137594
#  CELL 9                                  1026933  110661  1137594
#  CELL 10                                 1023963  113631  1137594
#  CELL 11                                 1023386  114208  1137594
#  CELL 12                                 1026134  111460  1137594,
#                                              Off      On    TOTAL
#  <Cell Balancers>  09/20/2018, 06:48:27
#  CELL 1                                  1030651  106943  1137594
#  CELL 2                                  1028468  109126  1137594
#  CELL 3                                  1029476  108118  1137594
#  CELL 4                                  1027772  109822  1137594
#  CELL 5                                  1028446  109148  1137594
#  CELL 6                                  1027401  110193  1137594
#  CELL 7                                  1028428  109166  1137594
#  CELL 8                                  1026086  111508  1137594
#  CELL 9                                  1026933  110661  1137594
#  CELL 10                                 1023963  113631  1137594
#  CELL 11                                 1023386  114208  1137594
#  CELL 12                                 1026134  111460  1137594,
#                                              Off      On    TOTAL
#  <Cell Balancers>  09/20/2018, 07:02:46
#  CELL 1                                  1031490  106943  1138433
#  CELL 2                                  1029307  109126  1138433
#  CELL 3                                  1030315  108118  1138433
#  CELL 4                                  1028611  109822  1138433
#  CELL 5                                  1029285  109148  1138433
#  CELL 6                                  1028240  110193  1138433
#  CELL 7                                  1029266  109167  1138433
#  CELL 8                                  1026920  111513  1138433
#  CELL 9                                  1027759  110674  1138433
#  CELL 10                                 1024789  113644  1138433
#  CELL 11                                 1024212  114221  1138433
#  CELL 12                                 1026966  111467  1138433,
#                                              Off      On    TOTAL
#  <Cell Balancers>  10/22/2018, 09:34:57
#  CELL 1                                  1205892  124017  1329909
#  CELL 2                                  1203522  126387  1329909
#  CELL 3                                  1204627  125282  1329909
#  CELL 4                                  1202737  127172  1329909
#  CELL 5                                  1203374  126535  1329909
#  CELL 6                                  1202375  127534  1329909
#  CELL 7                                  1203451  126458  1329909
#  CELL 8                                  1200849  129060  1329909
#  CELL 9                                  1201890  128019  1329909
#  CELL 10                                 1198792  131117  1329909
#  CELL 11                                 1198258  131651  1329909
#  CELL 12                                 1201178  128731  1329909,
#                                              Off      On    TOTAL
#  <Cell Balancers>  10/22/2018, 10:04:39
#  CELL 1                                  1206222  124017  1330239
#  CELL 2                                  1203852  126387  1330239
#  CELL 3                                  1204957  125282  1330239
#  CELL 4                                  1203067  127172  1330239
#  CELL 5                                  1203704  126535  1330239
#  CELL 6                                  1202705  127534  1330239
#  CELL 7                                  1203781  126458  1330239
#  CELL 8                                  1201179  129060  1330239
#  CELL 9                                  1202220  128019  1330239
#  CELL 10                                 1199122  131117  1330239
#  CELL 11                                 1198588  131651  1330239
#  CELL 12                                 1201508  128731  1330239,
#                                              Off      On    TOTAL
#  <Cell Balancers>  12/05/2018, 13:35:24
#  CELL 1                                  1337296  139021  1476317
#  CELL 2                                  1334695  141622  1476317
#  CELL 3                                  1336036  140281  1476317
#  CELL 4                                  1333939  142378  1476317
#  CELL 5                                  1334675  141642  1476317
#  CELL 6                                  1333566  142751  1476317
#  CELL 7                                  1334795  141522  1476317
#  CELL 8                                  1331813  144504  1476317
#  CELL 9                                  1332972  143345  1476317
#  CELL 10                                 1329179  147138  1476317
#  CELL 11                                 1328647  147670  1476317
#  CELL 12                                 1332032  144285  1476317,
#                                              Off      On    TOTAL
#  <Cell Balancers>  12/06/2018, 06:30:40
#  CELL 1                                  1337296  139021  1476317
#  CELL 2                                  1334695  141622  1476317
#  CELL 3                                  1336036  140281  1476317
#  CELL 4                                  1333939  142378  1476317
#  CELL 5                                  1334675  141642  1476317
#  CELL 6                                  1333566  142751  1476317
#  CELL 7                                  1334795  141522  1476317
#  CELL 8                                  1331813  144504  1476317
#  CELL 9                                  1332972  143345  1476317
#  CELL 10                                 1329179  147138  1476317
#  CELL 11                                 1328647  147670  1476317
#  CELL 12                                 1332032  144285  1476317,
#                                              Off      On    TOTAL
#  <Cell Balancers>  12/26/2018, 08:11:19
#  CELL 1                                  1398105  142657  1540762
#  CELL 2                                  1394940  145822  1540762
#  CELL 3                                  1396352  144410  1540762
#  CELL 4                                  1393637  147125  1540762
#  CELL 5                                  1394737  146025  1540762
#  CELL 6                                  1393248  147514  1540762
#  CELL 7                                  1394708  146054  1540762
#  CELL 8                                  1390869  149893  1540762
#  CELL 9                                  1392755  148007  1540762
#  CELL 10                                 1388384  152378  1540762
#  CELL 11                                 1387765  152997  1540762
#  CELL 12                                 1392466  148296  1540762]

# %% [markdown]
# ## Visualizing the parsed data:

# %% [markdown]
# Our visualization functions take the parsed data from our data building functions to help visualize trends in swapped modules.

# %% [markdown]
# visualize_mod_changes: This function uses the count_mod_changes output to produce a heat map for all buses indicating when the modules have been changed (with a color change indicating the module has been changed). The heat map includes a drop down menu to select the desired bus.

# %%
build_data_vis.visualise_mod_changes(directory)
# Out:
# alt.Chart(...)

# %% [markdown]
# The function mod_change_statistics returns the average times changed per module across all buses represented in our dataset.

# %%
build_data_vis.mod_change_statistics(directory)
# Out:
# <AxesSubplot:xlabel='Module', ylabel='Average times changed'>

# %% [markdown]
# visualize_mod_time: This function uses the build_module_average_df output to visualize the distribution of time spent at each voltage in the voltage range for a given module. For example, running this function with the input of bus 1 and module 1 will return a graph with 12 plotted lines, one for each individual date in bus one, where the x axis is voltage and the y axis is time in seconds. A dropdown menu is available on the graph to select a specific date. The selected date will remain in color while the other dates will be rendered gray. The axes are also scalable by clicking and dragging and using your mouse scroll.

# %%
build_data_vis.visualize_mod_time(directory, 'bus_1/', 11)
# Out:
# alt.Chart(...)
