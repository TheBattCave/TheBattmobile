# %%
import build_data_vis

# %%
directory = build_data_vis.find_directory() + 'sorted_data/' + 'Cleaned_Buses/'

# %%
directory
# Out:
# '/mnt/c/Users/spris/Desktop/DIRECT/Capstone/KCM-Data/sorted_data/Cleaned_Buses/'

# %%
build_data_vis.visualise_mod_changes(directory)
# Out:
# alt.Chart(...)

# %%
build_data_vis.build_bus_df(directory, 'bus_1/', 'Current')
# Out:
#     < -350.0  -350  -340  -330  -320  -310  -300  -290  -280  -270  ...   270  \
# 0          0     0     0     0     0     2    10    77   529  3369  ...   937
# 1          0     0     0     0     0     2    10    77   529  3369  ...   937
# 2          0     0     0     0     0     3    13   102   706  4643  ...  1712
# 3          0     0     0     0     0     3    13   103   710  4703  ...  1782
# 4          0     0     0     0     0     3    13   103   710  4703  ...  1782
# 5          0     0     0     0     0     3    13   103   710  4703  ...  1782
# 6          0     0     0     0     0     8    28   202  1201  6258  ...  2551
# 7          0     0     0     0     0     8    28   202  1201  6258  ...  2551
# 8          0     0     0     0     0     8    28   202  1201  6258  ...  2551
# 9          0     0     0     0     0     8    28   202  1201  6258  ...  2551
# 10         0     0     0     0     0     8    28   202  1204  6270  ...  2555
# ...

# %%
build_data_vis.build_module_df(directory, 'bus_1/', 1)
# Out:
#      < 2.0  2  2.2  2.4   2.6     2.8        3       3.2      3.4     3.6  \
# 0        0  0    0    0   127  226879  2601804  13728787  2060319   81412
# 1        0  0    0    0    12  110505  2566545  14090318  1914435   17513
# 2        0  0    0    0   369  332949  2613591  13485229  2098514  168676
# 3        0  0    0    0    24  125100  2576091  14042824  1934353   20936
# 4        0  0    0    0   539  359234  2613940  13427657  2105483  192475
# ..     ... ..  ...  ...   ...     ...      ...       ...      ...     ...
# 211      0  0    0    0   510  190512  4083068  21651787  3054384   60660
# 212      0  0    0    0  1194  538432  4145804  20755450  3246999  353041
# 213      0  0    0    0   563  213689  4103070  21570151  3083451   69997
# 214      0  0    0    0   952  251073  4121799  21461983  3118184   86930
# 215      0  0    0    0  1201  454328  4153447  20916379  3256308  259258
#
#      3.8  >= 4.0     TOTAL
# 0      0       0  18699328
# ...

# %%
a =build_data_vis.build_module_average_df(directory, 'bus_1/', 1)

# %%
a = a.reset_index()

# %%
a
# Out:
#           DateRetrieved  < 2.0    2  2.2  2.4         2.6            2.8  \
# 0   2017-09-20 06:36:19    0.0  0.0  0.0  0.0  204.000000  218366.000000
# 1   2017-09-20 08:29:04    0.0  0.0  0.0  0.0  204.000000  218366.000000
# 2   2018-03-20 10:36:30    0.0  0.0  0.0  0.0  835.250000  307839.166667
# 3   2018-07-31 06:14:11    0.0  0.0  0.0  0.0  856.166667  333373.916667
# 4   2018-07-31 06:30:55    0.0  0.0  0.0  0.0  856.166667  333373.916667
# 5   2018-07-31 06:40:09    0.0  0.0  0.0  0.0  856.166667  333373.916667
# 6   2018-09-20 06:30:57    0.0  0.0  0.0  0.0  913.250000  361809.333333
# 7   2018-09-20 06:39:31    0.0  0.0  0.0  0.0  913.250000  361809.333333
# 8   2018-09-20 06:48:27    0.0  0.0  0.0  0.0  913.250000  361809.333333
# 9   2018-09-20 07:02:46    0.0  0.0  0.0  0.0  913.250000  361809.333333
# 10  2018-10-22 09:34:57    0.0  0.0  0.0  0.0  916.416667  363436.000000
# 11  2018-10-22 10:04:39    0.0  0.0  0.0  0.0  916.416667  363436.000000
# ...

# %%
build_data_vis.visualize_mod_time(directory, 'bus_1/', 1)
# Out:
# alt.Chart(...)
